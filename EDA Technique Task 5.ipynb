# %% [markdown]
# # Grip21Jan

# %% [markdown]
# # EDA TASK (IPL Dataset)

# %% [markdown]
# # The Spark Foundation

# %% [markdown]
# # Name:Muhammad Hassan Khan

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns
import squarify 
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
deliveries=pd.read_csv('deliveries.csv')
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
matches=pd.read_csv('matches.csv')
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.shape
# Out:
# (756, 18)

# %% [markdown]
# ## Explanatory Data Analysis

# %%
deliveries.dtypes
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
matches.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
deliveries.apply(lambda x : x.isnull().sum())
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
matches.apply(lambda x : x.isnull().sum())
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
deliveries.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %% [markdown]
# ## Univariate Analysis

# %%
categorical_column=deliveries.select_dtypes(include=['object', 'category']).columns
deliveries[categorical_column].apply(lambda x : len(x.unique()))
# Out:
# batting_team         15
# bowling_team         15
# batsman             516
# non_striker         511
# bowler              405
# player_dismissed    488
# dismissal_kind       10
# fielder             500
# dtype: int64

# %%
categorical_column=matches.select_dtypes(include=['object', 'category']).columns
matches[categorical_column].apply(lambda x : len(x.unique()))
# Out:
# city                33
# date               546
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# result               3
# winner              16
# player_of_match    227
# venue               41
# umpire1             62
# umpire2             66
# umpire3             26
# dtype: int64

# %%
plt.subplots(figsize=(25,7))
sns.barplot(matches['winner'].value_counts().index,matches['winner'].value_counts().values)
plt.title('Top winner teams')
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(25,7))
sns.barplot(matches['player_of_match'].value_counts()[0:10].index,matches['player_of_match'].value_counts()[0:10].values)
plt.title('Top players in IPL')
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(25,7))
deliveries.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar',color='black') 
plt.title('Most run  by the batsman')
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(25,7))
sns.barplot(matches['venue'].value_counts()[0:10].index,matches['venue'].value_counts()[0:10].values)
plt.title('Most venues consider in IPL')
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(25,7))
sns.barplot(matches['city'].value_counts().index,matches['city'].value_counts().values)

# %%
plt.subplots(figsize=(25,7))
group=matches.groupby('venue')['city'].count().sort_values(ascending=False)
sns.barplot(group.index, group.values) #(month, day)
plt.title('Most matches in the city')
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(25,7))
plt.pie(matches['toss_decision'].value_counts(), labels=matches['toss_decision'].value_counts().index, autopct='%1.1f%%', startangle=180)
plt.show()

# %%
plt.subplots(figsize=(35,7))
sns.barplot(matches[matches['toss_decision']=='field']['winner'].value_counts().index,
             matches[matches['toss_decision']=='field']['winner'].value_counts().values)
plt.show()

# %%
deliveries.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# batsman
# YK Pathan          3241
# Yuvraj Singh       2765
# Y Venugopal Rao     985
# Y Nagar             285
# YV Takawale         192
# Yashpal Singh        47
# YS Chahal            22
# Younis Khan           3
# YA Abdulla            0
# Name: batsman_runs, dtype: int64

# %%
deliveries.groupby(['batsman','batting_team'])['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# batsman         batting_team
# V Kohli         Royal Challengers Bangalore    5434
# SK Raina        Chennai Super Kings            4574
# MS Dhoni        Chennai Super Kings            3903
# AB de Villiers  Royal Challengers Bangalore    3757
# RG Sharma       Mumbai Indians                 3744
#                                                ...
# SN Thakur       Rising Pune Supergiant            0
# L Ablish        Kings XI Punjab                   0
# M Ashwin        Rising Pune Supergiants           0
# V Pratap Singh  Deccan Chargers                   0
# Harmeet Singh   Deccan Chargers                   0
# Name: batsman_runs, Length: 935, dtype: int64
